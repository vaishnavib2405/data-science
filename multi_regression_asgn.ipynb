# %% [markdown]
# #Toyota Corolla Problem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d733736e-65ae-4b2a-b256-b8d7998d268c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d733736e-65ae-4b2a-b256-b8d7998d268c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("ToyotaCorolla.csv", encoding='latin1')

# %%
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
df2=pd.concat([df.iloc[:,2:4],df.iloc[:,6:7],df.iloc[:,8:9],df.iloc[:,12:14],df.iloc[:,15:18]],axis=1)

# %%
df2.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
df3 = df2.rename({'Age_08_04' : 'Age', 'cc' : 'CC', 'Quarterly_Tax' : 'QT'}, axis = 1)

# %%
df3.head()
# Out:
#    Price  Age     KM  HP    CC  Doors  Gears   QT  Weight
# 0  13500   23  46986  90  2000      3      5  210    1165
# 1  13750   23  72937  90  2000      3      5  210    1165
# 2  13950   24  41711  90  2000      3      5  210    1165
# 3  14950   26  48000  90  2000      3      5  210    1165
# 4  13750   30  38500  90  2000      3      5  210    1170

# %%
df3[df3.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
df4 = df3.drop_duplicates()

# %%
df4[df4.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Price, Age, KM, HP, CC, Doors, Gears, QT, Weight]
# Index: []

# %%
df4.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df4)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1435 non-null   int64
#  1   Age     1435 non-null   int64
#  2   KM      1435 non-null   int64
#  3   HP      1435 non-null   int64
#  4   CC      1435 non-null   int64
#  5   Doors   1435 non-null   int64
#  6   Gears   1435 non-null   int64
#  7   QT      1435 non-null   int64
#  8   Weight  1435 non-null   int64
# dtypes: int64(9)
# memory usage: 112.1 KB

# %%
model = smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=df4).fit()

# %%
model.params
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):               0.00
# Time:                        10:33:24   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %%
test_data = df4.sample(1)

# %%
test_data
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears  QT  Weight
# 939  10250   60  54554  110  1600      3      6  85    1065

# %%
model.predict(test_data)
# Out:
# 939    11240.537187
# dtype: float64

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(df4)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(model,ax = ax)

# %% [markdown]
# #50 startups Problem

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aabc6c74-94e5-4a6b-9386-608fa9b44bfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aabc6c74-94e5-4a6b-9386-608fa9b44bfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
star = pd.read_csv('50_Startups.csv')

# %%
star.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
star.shape
# Out:
# (50, 5)

# %%
star.drop(['State'], axis = 1, inplace= True)

# %%
star.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
star.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
star[star.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, Profit]
# Index: []

# %%
star.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(star)

# %%
star1 = star.rename({'R&D Spend': 'RDS','Administration': 'ADM','Marketing Spend': 'MKS'}, axis=1)

# %%
star1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RDS     50 non-null     float64
#  1   ADM     50 non-null     float64
#  2   MKS     50 non-null     float64
#  3   Profit  50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
regmod = smf.ols('Profit~RDS+ADM+MKS',data=star1).fit()

# %%
regmod.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADM             -0.026816
# MKS              0.027228
# dtype: float64

# %%
regmod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):           4.53e-30
# Time:                        10:51:04   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
rsq_rds = smf.ols('RDS~ADM+MKS',data=star1).fit().rsquared
vif_rds = 1/(1-rsq_rds)
vif_rds
# Out:
# 2.4689030699947017

# %%
rsq_adm = smf.ols('ADM~RDS+MKS',data=star1).fit().rsquared
vif_adm = 1/(1-rsq_adm)
vif_adm
# Out:
# 1.1750910070550453

# %%
rsq_mks = smf.ols('MKS~RDS+ADM',data=star1).fit().rsquared
vif_mks = 1/(1-rsq_mks)
vif_mks
# Out:
# 2.326773290530878

# %%
d1 = {'Variables':['RDS','ADM','MKS'],'VIF':[vif_rds,vif_adm,vif_mks]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#   Variables       VIF
# 0       RDS  2.468903
# 1       ADM  1.175091
# 2       MKS  2.326773

# %%
#Going by the VIF values, none of the VIF values are less than 4, multicollinearity isnt a problem so we now plot influence plots
#This is being done to spot any extra influence by a single data point on the model and remove that datapoint to improve its accuracy.

# %%
regmod_influence = regmod.get_influence()
(c, _) = regmod_influence.cooks_distance

# %%
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(star1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(regmod,ax = ax)

# %%
#Here we see that the datapoint at index number 49 is having way too much influence on the model.Hence we remove this entry and make a new model.

# %%
star1[star1.index.isin([49])]
# Out:
#     RDS       ADM       MKS   Profit
# 49  0.0  116983.8  45173.06  14681.4

# %%
star2=star1.drop(star1.index[[49]],axis=0).reset_index(drop=True)
star2.head()
# Out:
#          RDS        ADM        MKS     Profit
# 0  165349.20  136897.80  471784.10  192261.83
# 1  162597.70  151377.59  443898.53  191792.06
# 2  153441.51  101145.55  407934.54  191050.39
# 3  144372.41  118671.85  383199.62  182901.99
# 4  142107.34   91391.77  366168.42  166187.94

# %%
regmod_final = smf.ols('Profit~RDS+ADM+MKS',data=star2).fit()

# %%
regmod_final.params
# Out:
# Intercept    52382.439251
# RDS              0.783002
# ADM             -0.022201
# MKS              0.025234
# dtype: float64

# %%
regmod_final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):           8.85e-32
# Time:                        11:00:08   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.238e+04   5542.657      9.451      0.000    4.12e+04    6.35e+04
# ...

# %%
test = star2.sample(1)
test
# Out:
#          RDS       ADM        MKS     Profit
# 20  76253.86  113867.3  298664.47  118474.03

# %%
regmod_final.predict(test)
# Out:
# 20    117097.731866
# dtype: float64

# %%
d2={'Prepared_models':['regmod','regmod_final'],'Rsquared':[regmod.rsquared,regmod_final.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#   Prepared_models  Rsquared
# 0          regmod  0.950746
# 1    regmod_final  0.961316

# %%
#Hence we have an improved model with higher accuracy
