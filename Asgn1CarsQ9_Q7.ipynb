# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7e734024-fa80-4400-a832-cb8c2b89d676" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e734024-fa80-4400-a832-cb8c2b89d676">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("Q9_a.csv")

# %%
data.shape
# Out:
# (50, 3)

# %%
data.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
data.kurtosis()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-26fe85c8-e2a0-4a3a-b053-f6dc7cd47c32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26fe85c8-e2a0-4a3a-b053-f6dc7cd47c32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_1=pd.read_csv("Q9_b.csv")

# %%
data_1.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
data_1.kurtosis()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-508f4905-96c4-4fce-932a-976a1b8db0e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-508f4905-96c4-4fce-932a-976a1b8db0e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Q7=pd.read_csv('Q7.csv')

# %%
Q7.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
Q7.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
Q7[['Points','Score','Weigh']].mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
Q7[['Points','Score','Weigh']].median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
Q7[['Points','Score','Weigh']].mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
Q7[['Points','Score','Weigh']].std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
from statistics import variance

# importing fractions as parameter values
from fractions import Fraction as fr

# %%
Q7.var()
# Out:
# <ipython-input-8-ccab31effceb>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q7.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9ea7e4b0-e3bf-4001-809f-b235fdbe05ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ea7e4b0-e3bf-4001-809f-b235fdbe05ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cars=pd.read_csv('Cars.csv')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.mean()
# Out:
# HP     117.469136
# MPG     34.422076
# VOL     98.765432
# SP     121.540272
# WT      32.412577
# dtype: float64

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from scipy import stats

# %% [markdown]
# **P(MPG>38)**

# %%
1-stats.norm.cdf(38,34.422076,9.131445)
# Out:
# 0.34759394041453007

# %% [markdown]
# **P(MPG<40)**

# %%
stats.norm.cdf(40,34.422076,9.131445)
# Out:
# 0.7293498604157946

# %% [markdown]
# **P(20<MPG<50)**

# %%
stats.norm.cdf(0.50,34.422076,9.131445)-stats.norm.cdf(0.20,34.422076,9.131445)
# Out:
# 1.2430972133282213e-05

# %% [markdown]
# check whether the MPG of cars follows the normal distribution

# %%
cars['MPG'].mode()
# Out:
# 0    29.629936
# Name: MPG, dtype: float64

# %%
cars['MPG'].mean()
# Out:
# 34.42207572802469

# %%
cars['MPG'].median()
# Out:
# 35.15272697
